# %%
from pathlib import Path
import os

ROOT = Path("/Users/prathiksharamesh/single-cell-lung-atlas-covid19")

print(ROOT)
# Out:
# /Users/prathiksharamesh/single-cell-lung-atlas-covid19

# %%
import scanpy as sc 
adata = sc.read_h5ad(ROOT/"data" / "processed" / "combined.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 108822 × 29581
#     obs: 'Sample', 'doublet', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo'
#     var: 'n_cells'
